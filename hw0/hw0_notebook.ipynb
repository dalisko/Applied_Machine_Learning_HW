# %%
import csv
import os
#from google.colab import files
import pandas as pd
import io
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2a08b89e-6457-455b-882b-9d5ebe494660" name="files[]" multiple disabled />
#      <output id="result-2a08b89e-6457-455b-882b-9d5ebe494660">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving iris.data to iris.data

# %% [markdown]
# ##ORIE 5750 - Homework 0
#
# ###Maxwell Wulff mcw232 , Konstantinos Ntalis kn442

# %% [markdown]
# ##Problem 3

# %%
#uploaded = files.upload()
iris = pd.read_csv(io.BytesIO(uploaded['iris.data']) , header = None)
iris.columns = ["sepal length" , "sepal width" , "petal length" , "petal width" , "species" ]

# %%
species = iris['species']
print(species.value_counts())
# Out:
# Iris-virginica     50
# Iris-versicolor    50
# Iris-setosa        50
# Name: species, dtype: int64

# %% [markdown]
# **1a.** There are 4 attributes and 1 classification
#
# **1b.** There are 3 species, 50 of each

# %% [markdown]
# **3.**

# %%
sns.pairplot(iris, hue = 'species')
